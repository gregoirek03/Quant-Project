# %%
# 🏋️ Le calcul de la Matrice de Corrélation
# Une matrice X de taille N*P 
# --> Écris une fonction qui retourne la matrice de corrélation 

# ❌ L'erreur de débutant
# Vouloir créer une matrice vide de taille P*P
# Puis faire une double boucle for --> trop lent

# 🚀 La logique Quant (Algèbre Linéaire)
# Appliquer la formule mathématique avec les fonctions numpy

# %%
import numpy as np

def matrice_correlation(X: np.ndarray) -> np.ndarray:
    # 1. On récupère le nombre de lignes (N) et de colonnes (P)
    N, P = X.shape
    
    # 2. On utilise notre fonction précédente pour centrer/réduire X
    X_norm = normaliser_matrice(X) # (Moyenne 0, Écart-type 1)
    
    # 3. Multiplication matricielle pure
    # X_norm.T est de taille (P, N) et X_norm est de taille (N, P)
    # Le produit @ donne bien une matrice (P, P)
    R = (X_norm.T @ X_norm) / (N - 1)
    
    return R
